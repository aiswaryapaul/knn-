# %% [markdown]
# <a href="https://colab.research.google.com/github/aiswaryapaul/knn-/blob/main/KNN_handson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://drive.google.com/file/d/1DnX2E2c0GZkgMwrlEVSIy_w1u0Lk1z9W/view?usp=sharing

# %%
*****
000000000

# %%
*/0

# %%
**0**00**0* x000**000**
x=0

# %%
import pandas as pd

# %%
df=pd.read_csv(r'/content/dataset (1).csv')

# %%
df
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4572 non-null   object
#  5   Symptom_5   3714 non-null   object
#  6   Symptom_6   2934 non-null   object
#  7   Symptom_7   2268 non-null   object
#  8   Symptom_8   1944 non-null   object
#  9   Symptom_9   1692 non-null   object
#  10  Symptom_10  1512 non-null   object
#  11  Symptom_11  1194 non-null   object
#  12  Symptom_12  744 non-null    object
#  13  Symptom_13  504 non-null    object
#  14  Symptom_14  306 non-null    object
#  15  Symptom_15  240 non-null    object
#  16  Symptom_16  192 non-null    object
#  17  Symptom_17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
df.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# Disease        0.000000
# Symptom_1      0.000000
# Symptom_2      0.000000
# Symptom_3      0.000000
# Symptom_4      7.073171
# Symptom_5     24.512195
# Symptom_6     40.365854
# Symptom_7     53.902439
# Symptom_8     60.487805
# Symptom_9     65.609756
# Symptom_10    69.268293
# Symptom_11    75.731707
# Symptom_12    84.878049
# Symptom_13    89.756098
# Symptom_14    93.780488
# Symptom_15    95.121951
# Symptom_16    96.097561
# Symptom_17    98.536585
# dtype: float64

# %%
df.columns
# Out:
# Index(['Disease', 'Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4',
#        'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9',
#        'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14',
#        'Symptom_15', 'Symptom_16', 'Symptom_17'],
#       dtype='object')

# %%
df.drop(['Symptom_7', 'Symptom_8', 'Symptom_9',
       'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14',
       'Symptom_15', 'Symptom_16', 'Symptom_17'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Disease    4920 non-null   object
#  1   Symptom_1  4920 non-null   object
#  2   Symptom_2  4920 non-null   object
#  3   Symptom_3  4920 non-null   object
#  4   Symptom_4  4572 non-null   object
#  5   Symptom_5  3714 non-null   object
#  6   Symptom_6  2934 non-null   object
# dtypes: object(7)
# memory usage: 269.2+ KB

# %%
df.isnull().sum()*100/len(df)
# Out:
# Disease       0.000000
# Symptom_1     0.000000
# Symptom_2     0.000000
# Symptom_3     0.000000
# Symptom_4     7.073171
# Symptom_5    24.512195
# Symptom_6    40.365854
# dtype: float64

# %%
df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6
# 0   dischromic _patches       NaN       NaN
# 1                   NaN       NaN       NaN
# 2                   NaN       NaN       NaN
# 3                   NaN       NaN       NaN
# 4                   NaN       NaN       NaN

# %%
for col in df.columns:
  print(f"{col}:{df[col].unique()}")
# Out:
# Disease:['Fungal infection' 'Allergy' 'GERD' 'Chronic cholestasis' 'Drug Reaction'
#  'Peptic ulcer diseae' 'AIDS' 'Diabetes ' 'Gastroenteritis'
#  'Bronchial Asthma' 'Hypertension ' 'Migraine' 'Cervical spondylosis'
#  'Paralysis (brain hemorrhage)' 'Jaundice' 'Malaria' 'Chicken pox'
#  'Dengue' 'Typhoid' 'hepatitis A' 'Hepatitis B' 'Hepatitis C'
#  'Hepatitis D' 'Hepatitis E' 'Alcoholic hepatitis' 'Tuberculosis'
#  'Common Cold' 'Pneumonia' 'Dimorphic hemmorhoids(piles)' 'Heart attack'
#  'Varicose veins' 'Hypothyroidism' 'Hyperthyroidism' 'Hypoglycemia'
#  'Osteoarthristis' 'Arthritis' '(vertigo) Paroymsal  Positional Vertigo'
#  'Acne' 'Urinary tract infection' 'Psoriasis' 'Impetigo']
# Symptom_1:['itching' ' skin_rash' ' continuous_sneezing' ' shivering'
#  ' stomach_pain' ' acidity' ' vomiting' ' indigestion' ' muscle_wasting'
#  ' patches_in_throat' ' fatigue' ' weight_loss' ' sunken_eyes' ' cough'
#  ' headache' ' chest_pain' ' back_pain' ' weakness_in_limbs' ' chills'
# ...

# %%
df.columns
# Out:
# Index(['Disease', 'Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4',
#        'Symptom_5', 'Symptom_6'],
#       dtype='object')

# %%
x=['Symptom_4','Symptom_5', 'Symptom_6']

# %%
df['Symptom_4'].mode()[0]
# Out:
# ' high_fever'

# %%
for col in x:
  df[col].fillna(df[col].mode()[0],inplace=True)
# Out:
# <ipython-input-18-7cbbfb03219e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Disease      0
# Symptom_1    0
# Symptom_2    0
# Symptom_3    0
# Symptom_4    0
# Symptom_5    0
# Symptom_6    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(4658)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Disease    4920 non-null   object
#  1   Symptom_1  4920 non-null   object
#  2   Symptom_2  4920 non-null   object
#  3   Symptom_3  4920 non-null   object
#  4   Symptom_4  4920 non-null   object
#  5   Symptom_5  4920 non-null   object
#  6   Symptom_6  4920 non-null   object
# dtypes: object(7)
# memory usage: 269.2+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#               Disease    Symptom_1              Symptom_2  \
# 0    Fungal infection      itching              skin_rash
# 1    Fungal infection    skin_rash   nodal_skin_eruptions
# 2    Fungal infection      itching   nodal_skin_eruptions
# 3    Fungal infection      itching              skin_rash
# 4    Fungal infection      itching              skin_rash
# ..                ...          ...                    ...
# 402          Impetigo   high_fever                blister
# 403          Impetigo    skin_rash                blister
# 405          Impetigo    skin_rash             high_fever
# 406          Impetigo    skin_rash             high_fever
# 407          Impetigo    skin_rash             high_fever
#
#                  Symptom_3              Symptom_4  Symptom_5 Symptom_6
# 0     nodal_skin_eruptions    dischromic _patches   headache    nausea
# 1      dischromic _patches             high_fever   headache    nausea
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 262 entries, 0 to 407
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Disease    262 non-null    object
#  1   Symptom_1  262 non-null    object
#  2   Symptom_2  262 non-null    object
#  3   Symptom_3  262 non-null    object
#  4   Symptom_4  262 non-null    object
#  5   Symptom_5  262 non-null    object
#  6   Symptom_6  262 non-null    object
# dtypes: object(7)
# memory usage: 16.4+ KB

# %%
df['Disease'].unique()
# Out:
# array(['Fungal infection', 'Allergy', 'GERD', 'Chronic cholestasis',
#        'Drug Reaction', 'Peptic ulcer diseae', 'AIDS', 'Diabetes ',
#        'Gastroenteritis', 'Bronchial Asthma', 'Hypertension ', 'Migraine',
#        'Cervical spondylosis', 'Paralysis (brain hemorrhage)', 'Jaundice',
#        'Malaria', 'Chicken pox', 'Dengue', 'Typhoid', 'hepatitis A',
#        'Hepatitis B', 'Hepatitis C', 'Hepatitis D', 'Hepatitis E',
#        'Alcoholic hepatitis', 'Tuberculosis', 'Common Cold', 'Pneumonia',
#        'Dimorphic hemmorhoids(piles)', 'Heart attack', 'Varicose veins',
#        'Hypothyroidism', 'Hyperthyroidism', 'Hypoglycemia',
#        'Osteoarthristis', 'Arthritis',
#        '(vertigo) Paroymsal  Positional Vertigo', 'Acne',
#        'Urinary tract infection', 'Psoriasis', 'Impetigo'], dtype=object)

# %%
df['Symptom_1'].unique()
# Out:
# array(['itching', ' skin_rash', ' continuous_sneezing', ' shivering',
#        ' stomach_pain', ' acidity', ' vomiting', ' indigestion',
#        ' muscle_wasting', ' patches_in_throat', ' fatigue',
#        ' weight_loss', ' sunken_eyes', ' cough', ' headache',
#        ' chest_pain', ' back_pain', ' weakness_in_limbs', ' chills',
#        ' joint_pain', ' yellowish_skin', ' constipation',
#        ' pain_during_bowel_movements', ' breathlessness', ' cramps',
#        ' weight_gain', ' mood_swings', ' neck_pain', ' muscle_weakness',
#        ' stiff_neck', ' pus_filled_pimples', ' burning_micturition',
#        ' bladder_discomfort', ' high_fever'], dtype=object)

# %%
df['Symptom_1'].value_counts()
# Out:
# Symptom_1
#  vomiting                       43
#  fatigue                        39
# itching                         33
#  joint_pain                     25
#  skin_rash                      24
#  chills                         24
#  continuous_sneezing            10
#  acidity                         7
#  headache                        7
#  stomach_pain                    6
#  muscle_weakness                 5
#  constipation                    5
#  back_pain                       5
#  burning_micturition             4
#  muscle_wasting                  4
#  indigestion                     2
#  yellowish_skin                  2
#  shivering                       1
#  weakness_in_limbs               1
#  chest_pain                      1
#  sunken_eyes                     1
#  cough                           1
#  weight_loss                     1
#  patches_in_throat               1
#  pain_during_bowel_movements     1
#  breathlessness                  1
# ...

# %%
#label encoding:
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in df.columns:
  if df[col].dtype=='object':
    df[col]=le.fit_transform(df[col])
    print(le.classes_)
# Out:
# ['(vertigo) Paroymsal  Positional Vertigo' 'AIDS' 'Acne'
#  'Alcoholic hepatitis' 'Allergy' 'Arthritis' 'Bronchial Asthma'
#  'Cervical spondylosis' 'Chicken pox' 'Chronic cholestasis' 'Common Cold'
#  'Dengue' 'Diabetes ' 'Dimorphic hemmorhoids(piles)' 'Drug Reaction'
#  'Fungal infection' 'GERD' 'Gastroenteritis' 'Heart attack' 'Hepatitis B'
#  'Hepatitis C' 'Hepatitis D' 'Hepatitis E' 'Hypertension '
#  'Hyperthyroidism' 'Hypoglycemia' 'Hypothyroidism' 'Impetigo' 'Jaundice'
#  'Malaria' 'Migraine' 'Osteoarthristis' 'Paralysis (brain hemorrhage)'
#  'Peptic ulcer diseae' 'Pneumonia' 'Psoriasis' 'Tuberculosis' 'Typhoid'
#  'Urinary tract infection' 'Varicose veins' 'hepatitis A']
# [' acidity' ' back_pain' ' bladder_discomfort' ' breathlessness'
#  ' burning_micturition' ' chest_pain' ' chills' ' constipation'
#  ' continuous_sneezing' ' cough' ' cramps' ' fatigue' ' headache'
#  ' high_fever' ' indigestion' ' joint_pain' ' mood_swings'
# ...

# %%
df
# Out:
#      Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  Symptom_6
# 0         15         33         35         35         11         12         20
# 1         15         24         27         18         19         12         20
# 2         15         33         27         18         19         12         20
# 3         15         33         35         18         19         12         20
# 4         15         33         35         35         19         12         20
# ..       ...        ...        ...        ...        ...        ...        ...
# 402       27         13          5         38         47         12         20
# 403       27         24          5         38         47         12         20
# 405       27         24         18         38         47         12         20
# 406       27         24         18          4         47         12         20
# 407       27         24         18          4         33         12         20
#
# [262 rows x 7 columns]

# %%
x=df.drop('Disease',axis=1)
y=df['Disease']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import *

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.33962264150943394

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={'n_neighbors':[5,7,8,10]}

# %%
grid=GridSearchCV(estimator=knn,param_grid=params,verbose=2)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=8; total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'n_neighbors': 5}

# %%
df=pd.read_csv(r'/content/dataset (1).csv')

# %%
df.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %%
import numpy as np

# %%
for col in df.columns:
  df[col]=df[col].replace(np.nan,'None')

# %%
df.isnull().sum()
# Out:
# Disease       0
# Symptom_1     0
# Symptom_2     0
# Symptom_3     0
# Symptom_4     0
# Symptom_5     0
# Symptom_6     0
# Symptom_7     0
# Symptom_8     0
# Symptom_9     0
# Symptom_10    0
# Symptom_11    0
# Symptom_12    0
# Symptom_13    0
# Symptom_14    0
# Symptom_15    0
# Symptom_16    0
# Symptom_17    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4920 non-null   object
#  5   Symptom_5   4920 non-null   object
#  6   Symptom_6   4920 non-null   object
#  7   Symptom_7   4920 non-null   object
#  8   Symptom_8   4920 non-null   object
#  9   Symptom_9   4920 non-null   object
#  10  Symptom_10  4920 non-null   object
#  11  Symptom_11  4920 non-null   object
#  12  Symptom_12  4920 non-null   object
#  13  Symptom_13  4920 non-null   object
#  14  Symptom_14  4920 non-null   object
#  15  Symptom_15  4920 non-null   object
#  16  Symptom_16  4920 non-null   object
#  17  Symptom_17  4920 non-null   object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(4616)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 304 entries, 0 to 407
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     304 non-null    object
#  1   Symptom_1   304 non-null    object
#  2   Symptom_2   304 non-null    object
#  3   Symptom_3   304 non-null    object
#  4   Symptom_4   304 non-null    object
#  5   Symptom_5   304 non-null    object
#  6   Symptom_6   304 non-null    object
#  7   Symptom_7   304 non-null    object
#  8   Symptom_8   304 non-null    object
#  9   Symptom_9   304 non-null    object
#  10  Symptom_10  304 non-null    object
#  11  Symptom_11  304 non-null    object
#  12  Symptom_12  304 non-null    object
#  13  Symptom_13  304 non-null    object
#  14  Symptom_14  304 non-null    object
#  15  Symptom_15  304 non-null    object
#  16  Symptom_16  304 non-null    object
#  17  Symptom_17  304 non-null    object
# dtypes: object(18)
# memory usage: 45.1+ KB

# %%
for col in df.columns:
  if df[col].dtype=='object':
    df[col]=le.fit_transform(df[col])
    print(le.classes_)
# Out:
# ['(vertigo) Paroymsal  Positional Vertigo' 'AIDS' 'Acne'
#  'Alcoholic hepatitis' 'Allergy' 'Arthritis' 'Bronchial Asthma'
#  'Cervical spondylosis' 'Chicken pox' 'Chronic cholestasis' 'Common Cold'
#  'Dengue' 'Diabetes ' 'Dimorphic hemmorhoids(piles)' 'Drug Reaction'
#  'Fungal infection' 'GERD' 'Gastroenteritis' 'Heart attack' 'Hepatitis B'
#  'Hepatitis C' 'Hepatitis D' 'Hepatitis E' 'Hypertension '
#  'Hyperthyroidism' 'Hypoglycemia' 'Hypothyroidism' 'Impetigo' 'Jaundice'
#  'Malaria' 'Migraine' 'Osteoarthristis' 'Paralysis (brain hemorrhage)'
#  'Peptic ulcer diseae' 'Pneumonia' 'Psoriasis' 'Tuberculosis' 'Typhoid'
#  'Urinary tract infection' 'Varicose veins' 'hepatitis A']
# [' acidity' ' back_pain' ' bladder_discomfort' ' breathlessness'
#  ' burning_micturition' ' chest_pain' ' chills' ' constipation'
#  ' continuous_sneezing' ' cough' ' cramps' ' fatigue' ' headache'
#  ' high_fever' ' indigestion' ' joint_pain' ' mood_swings'
# ...

# %%
df
# Out:
#      Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 0         15         33         35         35         11         38
# 1         15         24         27         18         50         38
# 2         15         33         27         18         50         38
# 3         15         33         35         18         50         38
# 4         15         33         35         35         50         38
# ..       ...        ...        ...        ...        ...        ...
# 402       27         13          5         38         47         38
# 403       27         24          5         38         47         38
# 405       27         24         18         38         47         38
# 406       27         24         18          4         47         38
# 407       27         24         18          4         33         38
#
#      Symptom_6  Symptom_7  Symptom_8  Symptom_9  Symptom_10  Symptom_11  \
# 0           32         26         21         22          21          18
# ...

# %%
x=df.drop('Disease',axis=1)
y=df['Disease']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5409836065573771
